# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from numpy.linalg import eig
from numpy import arange, zeros, cos, ones
from scipy.signal import StateSpace, lsim, step, impulse, bode
from matplotlib.pyplot import plot,axis,show,xlabel,ylabel,title,grid,legend, semilogx

# data
d1 = 1/0.02
d2 = 1/0.002
k1 = d1
k2 = d2

# state space matrices
A = [[-d1,0.0],[k2,-d2]]
B = [[k1],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)


if all(eig_value < 0 for eig_value in eig(A)[0]): print('Stable system')
else: print('Unstable system')
    

t = arange(0,0.10,0.001) 
u = zeros(len(t))

t1,y1,x1 = lsim(syst,u,t,[0.5,1])
t2,y2,x2 = lsim(syst,u,t,[2,1])
t3,y3,x3 = lsim(syst,u,t,[1,1])

plot(t,y1,'r--',label='(m,p)=(0.5,1)')
plot(t,y2,'b--',label='(m,p)=(2,1)')
plot(t,y3,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()
# Out:
# Stable system

# %%
t_step,y_step = step(syst,T=t)
plot(t,y_step)
title('Step response of the system')
xlabel('time(s)')
ylabel('amplitude')
grid(True)
show()

t_imp, y_imp = impulse(syst,T=t)
plot(t,y_imp)
title('Impulse response of the system')
xlabel('time(s)')
ylabel('amplitude')
grid(True)
show()

# %%
t = arange(0,6,0.001)

t4,y4,x4 = lsim(syst,cos(t)    ,t)
t5,y5,x5 = lsim(syst,cos(10*t) ,t)
t6,y6,x6 = lsim(syst,cos(100*t),t)

plot(t,y4,'r',label='1 rad/s',linewidth=2.0)
plot(t,y5,'b',label='10 rad/s',linewidth=1.0)
plot(t,y6,'g',label='100 rad/s',linewidth=0.5)

title('Simulated output acc. different cosine inputs')
xlabel('time(s)')
ylabel('amplitude')
legend(bbox_to_anchor=(1.05, 1), loc=2)
show()

# %%
print('Bode Diagram')

freq, amp, phase = bode(syst)
semilogx(freq,amp)
title('Amplitude plot')
ylabel('Amplitude (dB)')
xlabel('Frequency')
grid(True)
show()

semilogx(freq,phase)
title('Phase plot')
ylabel('Phase (deg)')
xlabel('Frequency')
grid(True)
show()
# Out:
# Bode Diagram

# %%
print('Effet de k1')
print('k1=')
# data
d1 = 50
d2 = 500
k1 = 50
k2 = 500

# state space matrices
A = [[-d1,0.0],[k2,-d2]]
B = [[k1],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)

if all(eig_value < 0 for eig_value in eig(A)[0]): print('Stable system')
else: print('Unstable system')  

t = arange(0,0.10,0.001) 
u = zeros(len(t))

t1,y1,x1 = lsim(syst,u,t,[0.5,1])
t2,y2,x2 = lsim(syst,u,t,[2,1])
t3,y3,x3 = lsim(syst,u,t,[1,1])

plot(t,y1,'r--',label='(m,p)=(0.5,1)')
plot(t,y2,'b--',label='(m,p)=(2,1)')
plot(t,y3,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()

print('k1>>')
# data
d1 = 50
d2 = 500
k1 = 2*50
k2 = 500

# state space matrices
A = [[-d1,0.0],[k2,-d2]]
B = [[k1],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)

if all(eig_value < 0 for eig_value in eig(A)[0]): print('Stable system')
else: print('Unstable system')

t = arange(0,0.10,0.001) 
u = zeros(len(t))

t4,y4,x4 = lsim(syst,u,t,[0.5,1])
t5,y5,x5 = lsim(syst,u,t,[2,1])
t6,y6,x6 = lsim(syst,u,t,[1,1])

plot(t,y4,'r--',label='(m,p)=(0.5,1)')
plot(t,y5,'b--',label='(m,p)=(2,1)')
plot(t,y6,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()

print('k1<<')
# data
d1 = 50
d2 = 500
k1 = 0.5*50
k2 = 500

# state space matrices
A = [[-d1,0.0],[k2,-d2]]
B = [[k1],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)

if all(eig_value < 0 for eig_value in eig(A)[0]): print('Stable system')
else: print('Unstable system')
    
t = arange(0,0.10,0.001) 
u = zeros(len(t))

t7,y7,x7 = lsim(syst,u,t,[0.5,1])
t8,y8,x8 = lsim(syst,u,t,[2,1])
t9,y9,x9 = lsim(syst,u,t,[1,1])

plot(t,y7,'r--',label='(m,p)=(0.5,1)')
plot(t,y8,'b--',label='(m,p)=(2,1)')
plot(t,y9,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()

plot(t3,y3,'g',label='initial k1')
plot(t6,y6,'r',label='bigger k1')
plot(t9,y9,'b',label='lower k1')

title('Simulated output acc. different k1 values')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()
# Out:
# Effet de k1
# k1=
# Stable system
# k1>>
# Stable system
# k1<<
# Stable system

# %%
print('Effet de k2')
print('k2=')
# data
d1 = 50
d2 = 500
k1 = 50
k2 = 500

# state space matrices
A = [[-d1,0.0],[k2,-d2]]
B = [[k1],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D) 

t = arange(0,0.10,0.001) 
u = zeros(len(t))

t1,y1,x1 = lsim(syst,u,t,[0.5,1])
t2,y2,x2 = lsim(syst,u,t,[2,1])
t3,y3,x3 = lsim(syst,u,t,[1,1])

plot(t,y1,'r--',label='(m,p)=(0.5,1)')
plot(t,y2,'b--',label='(m,p)=(2,1)')
plot(t,y3,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()

print('k2>>')
# data
d1 = 50
d2 = 500
k1 = 50
k2 = 2*500

# state space matrices
A = [[-d1,0.0],[k2,-d2]]
B = [[k1],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)

t4,y4,x4 = lsim(syst,u,t,[0.5,1])
t5,y5,x5 = lsim(syst,u,t,[2,1])
t6,y6,x6 = lsim(syst,u,t,[1,1])

plot(t,y4,'r--',label='(m,p)=(0.5,1)')
plot(t,y5,'b--',label='(m,p)=(2,1)')
plot(t,y6,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()

print('k2<<')
# data
d1 = 50
d2 = 500
k1 = 50
k2 = 0.5*500

# state space matrices
A = [[-d1,0.0],[k2,-d2]]
B = [[k1],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)

t7,y7,x7 = lsim(syst,u,t,[0.5,1])
t8,y8,x8 = lsim(syst,u,t,[2,1])
t9,y9,x9 = lsim(syst,u,t,[1,1])

plot(t,y7,'r--',label='(m,p)=(0.5,1)')
plot(t,y8,'b--',label='(m,p)=(2,1)')
plot(t,y9,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()


plot(t3,y3,'g',label='initial k2')
plot(t6,y6,'r',label='bigger k2')
plot(t9,y9,'b',label='lower k2')

title('Simulated output acc. different k2 values')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()
# Out:
# Effet de k2
# k2=
# k2>>
# k2<<

# %%
print('Effet de d1')
print('d1=')
# data
d1 = 50
d2 = 500
k1 = 50
k2 = 500

# state space matrices
A = [[-d1,0.0],[k2,-d2]]
B = [[k1],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)

t1,y1,x1 = lsim(syst,u,t,[0.5,1])
t2,y2,x2 = lsim(syst,u,t,[2,1])
t3,y3,x3 = lsim(syst,u,t,[1,1])

plot(t,y1,'r--',label='(m,p)=(0.5,1)')
plot(t,y2,'b--',label='(m,p)=(2,1)')
plot(t,y3,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()
print('d1>>')
# data
d1 = 2*50
d2 = 500
k1 = 50
k2 = 500

# state space matrices
A = [[-d1,0.0],[k2,-d2]]
B = [[k1],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)

t4,y4,x4 = lsim(syst,u,t,[0.5,1])
t5,y5,x5 = lsim(syst,u,t,[2,1])
t6,y6,x6 = lsim(syst,u,t,[1,1])

plot(t,y4,'r--',label='(m,p)=(0.5,1)')
plot(t,y5,'b--',label='(m,p)=(2,1)')
plot(t,y6,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()

print('d1<<')
# data
d1 = 0.5*50
d2 = 500
k1 = 50
k2 = 500

# state space matrices
A = [[-d1,0.0],[k2,-d2]]
B = [[k1],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)

t7,y7,x7 = lsim(syst,u,t,[0.5,1])
t8,y8,x8 = lsim(syst,u,t,[2,1])
t9,y9,x9 = lsim(syst,u,t,[1,1])

plot(t,y7,'r--',label='(m,p)=(0.5,1)')
plot(t,y8,'b--',label='(m,p)=(2,1)')
plot(t,y9,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()


plot(t3,y3,'g',label='initial d1')
plot(t6,y6,'r',label='bigger d1')
plot(t9,y9,'b',label='lower d1')

title('Simulated output acc. different d1 values')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()
# Out:
# Effet de d1
# d1=
# d1>>
# d1<<

# %%
print('Effet de d2')
print('d2=')
# data
d1 = 50
d2 = 500
k1 = 50
k2 = 500

# state space matrices
A = [[-d1,0.0],[k2,-d2]]
B = [[k1],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)

t1,y1,x1 = lsim(syst,u,t,[0.5,1])
t2,y2,x2 = lsim(syst,u,t,[2,1])
t3,y3,x3 = lsim(syst,u,t,[1,1])

plot(t,y1,'r--',label='(m,p)=(0.5,1)')
plot(t,y2,'b--',label='(m,p)=(2,1)')
plot(t,y3,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()

print('d2>>')
# data
d1 = 50
d2 = 2*500
k1 = 50
k2 = 500

# state space matrices
A = [[-d1,0.0],[k2,-d2]]
B = [[k1],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)

t4,y4,x4 = lsim(syst,u,t,[0.5,1])
t5,y5,x5 = lsim(syst,u,t,[2,1])
t6,y6,x6 = lsim(syst,u,t,[1,1])

plot(t,y4,'r--',label='(m,p)=(0.5,1)')
plot(t,y5,'b--',label='(m,p)=(2,1)')
plot(t,y6,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()

print('d2<<')
# data
d1 = 50
d2 = 0.5*500
k1 = 50
k2 = 500

# state space matrices
A = [[-d1,0.0],[k2,-d2]]
B = [[k1],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)

t7,y7,x7 = lsim(syst,u,t,[0.5,1])
t8,y8,x8 = lsim(syst,u,t,[2,1])
t9,y9,x9 = lsim(syst,u,t,[1,1])

plot(t,y7,'r--',label='(m,p)=(0.5,1)')
plot(t,y8,'b--',label='(m,p)=(2,1)')
plot(t,y9,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()


plot(t3,y3,'g',label='initial d2')
plot(t6,y6,'r',label='bigger d2')
plot(t9,y9,'b',label='lower d2')

title('Simulated output acc. different d2 values')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()
# Out:
# Effet de d2
# d2=
# d2>>
# d2<<

# %%
# state space matrices
A = [[-50.0,0.0],[500.0,-500.0]]
B = [[0.0],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)


if all(eig_value < 0 for eig_value in eig(A)[0]): print('Stable system')
else: print('Unstable system')
    

t = arange(0,0.10,0.001) 
u = zeros(len(t))

t1,y1,x1 = lsim(syst,u,t,[0.5,1])
t2,y2,x2 = lsim(syst,u,t,[2,1])
t3,y3,x3 = lsim(syst,u,t,[1,1])

plot(t,y1,'r--',label='(m,p)=(0.5,1)')
plot(t,y2,'b--',label='(m,p)=(2,1)')
plot(t,y3,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()
# Out:
# Stable system

# %%
# state space matrices
A = [[-50.0,7.8125],[500.0,-500.0]]
B = [[25.0],[0.0]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)


if all(eig_value < 0 for eig_value in eig(A)[0]): print('Stable system')
else: print('Unstable system')
    

t = arange(0,0.10,0.001) 
u = zeros(len(t))

t1,y1,x1 = lsim(syst,u,t,[0.5,1])
t2,y2,x2 = lsim(syst,u,t,[2,1])
t3,y3,x3 = lsim(syst,u,t,[1,1])

plot(t,y1,'r--',label='(m,p)=(0.5,1)')
plot(t,y2,'b--',label='(m,p)=(2,1)')
plot(t,y3,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()
# Out:
# Stable system

# %%
# state space matrices
A = [[-50.0,7.8125],[500.0,-500.0]]
B = [[0.0],[48.1891]]
C = [0.0,1.0]
D = [0.0]

# linear time invariant system
syst = StateSpace(A,B,C,D)


if all(eig_value < 0 for eig_value in eig(A)[0]): print('Stable system')
else: print('Unstable system')
    

t = arange(0,0.10,0.001) 
u = zeros(len(t))

t1,y1,x1 = lsim(syst,u,t,[0.5,1])
t2,y2,x2 = lsim(syst,u,t,[2,1])
t3,y3,x3 = lsim(syst,u,t,[1,1])

plot(t,y1,'r--',label='(m,p)=(0.5,1)')
plot(t,y2,'b--',label='(m,p)=(2,1)')
plot(t,y3,'g--',label='(m,p)=(1,1)')

title('Simulated output acc. different initial conditions')
xlabel('time(s)')
ylabel('protein concentration')
legend()
grid(True)
show()
# Out:
# Stable system
